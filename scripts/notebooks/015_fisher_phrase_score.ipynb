# %% [markdown]
# # calculate phrase contribution to image selection using fisher exact text
#
# input:
# - rank data: pairs with selection labels
#
#     I load them from ranking_data/*.json
#
# - prompt list: str, (positive or negative)
#
#     I load them from *_data.msgpack
#
# output: phrase contribution list csv with 5 fiedls:
# - phrase: str
# - num_select: frequency of this phrase contained in prompts of selected images
# - num_unselect: frequency of this phrase contained in prompts of unselected images
# - odds_ratio: phrase contribution to selection
# - p_value: confidence, lower is better

# %%
import os
import sys
import json
import glob

from PIL import Image

import re

from scipy.stats import fisher_exact

import numpy as np
import pandas as pd

from matplotlib import pyplot

import msgpack

from tqdm.auto import tqdm

# %%
RANK_DIR = '../kcg-ml-image-pipeline/output/environmental/ranking_v1/'
DATA_DIR = '../kcg-ml-image-pipeline/output/dataset/data/'

# %% [markdown]
# # load rank data

# %%
paths = sorted(glob.glob(os.path.join(RANK_DIR, 'ranking_data', '*.json')))

rank_pairs = list()
for path in tqdm(paths):
    js = json.load(open(path))
    
    file_path_1 = os.path.splitext(js['image_1_metadata']['file_path'])[0].replace('datasets/', '')
    file_path_2 = os.path.splitext(js['image_2_metadata']['file_path'])[0].replace('datasets/', '')
    
    rank_pairs.append((file_path_1, file_path_2, js['selected_image_index']))
# Out:
#   0%|          | 0/49097 [00:00<?, ?it/s]

# %%
rank_pairs = pd.DataFrame(rank_pairs, columns=['image_1', 'image_2', 'selected_image_index'])
ordered_pairs = [((image_1, image_2) if selected_image_index == 0 else (image_2, image_1)) for image_1, image_2, selected_image_index in rank_pairs.itertuples(index=False, name=None)]

# %% [markdown]
# # stats phrase

# %%
def format_prompt(prompt):
    
    prompt = prompt.strip()
    
    while re.search(r'(\([\s,\.:;\|]*\))|(\<[\s,\.:;\|]*\>)|(\[[\s,\.:;\|]*\])|(\{[\s,\.:;\|]*\})', prompt):
        prompt = re.sub(r'(\([\s,\.:;\|]*\))|(\<[\s,\.:;\|]*\>)|(\[[\s,\.:;\|]*\])|(\{[\s,\.:;\|]*\})', '', prompt)
    
    prompt = re.sub(r'([\[\(\{\<])\s', r'\1', prompt)
    prompt = re.sub(r'\s([\]\)\}\>])', r'\1', prompt)
    prompt = re.sub(r'\s+', ' ', prompt)
    prompt = re.sub(r'(\s?[,;])+', r',', prompt)
    
    prompt = re.sub(r'^[\.,;\s]+', '', prompt)
    prompt = re.sub(r'[\.,;\s]+$', '', prompt)
    
    return prompt

def remove_weight(prompt):
    prompt = re.sub(':[-\s0-9,\.]*', ', ', prompt)
    prompt = re.sub(r'[\(\[\{\<\>\}\]\)]+', '', prompt)
    return prompt

def prompt_to_tags(prompt):
    
    prompt = format_prompt(prompt)
    prompt = remove_weight(prompt)
    prompt = format_prompt(prompt)
    
    for tag in prompt.split(','):
        tag = tag.strip()
        if len(tag) == 0:
            continue
        yield tag

# %%
def load_prompt_from_data(path):
    
    data = msgpack.load(open(path, 'rb'))
    
    return data['positive_prompt'], data['negative_prompt']

# %%
positive_stats = dict()
negative_stats = dict()

for image_1, image_2 in tqdm(ordered_pairs, leave=False):
    
    # selected 
    
    positive_prompt, negative_prompt = load_prompt_from_data(os.path.join(DATA_DIR, f'{image_1}_data.msgpack'))
    
    for tag in prompt_to_tags(positive_prompt):
        if tag not in positive_stats:
            positive_stats[tag] = [0, 0]
        positive_stats[tag][0] += 1
    
    for tag in prompt_to_tags(negative_prompt):
        if tag not in negative_stats:
            negative_stats[tag] = [0, 0]
        negative_stats[tag][0] += 1
    
    # unselected 
    
    positive_prompt, negative_prompt = load_prompt_from_data(os.path.join(DATA_DIR, f'{image_2}_data.msgpack'))
    
    for tag in prompt_to_tags(positive_prompt):
        if tag not in positive_stats:
            positive_stats[tag] = [0, 0]
        positive_stats[tag][1] += 1
    
    for tag in prompt_to_tags(negative_prompt):
        if tag not in negative_stats:
            negative_stats[tag] = [0, 0]
        negative_stats[tag][1] += 1
# Out:
#   0%|          | 0/49097 [00:00<?, ?it/s]

# %% [markdown]
# # get result

# %%
def stats_to_df(stats):
    
    df = pd.DataFrame(stats.values(), columns=['num_select', 'num_unselect'])
    df['phrase'] = stats.keys()
    df.set_index('phrase', inplace=True)
    
    n_total = len(ordered_pairs)

    os, ps = list(), list()
    for num_select, num_unselect in tqdm(df.itertuples(index=False, name=None), total=df.shape[0], leave=False):
        # if num_select + num_unselect < 100:
        #     os.append(-1)
        #     ps.append(-1)
        #     continue
        o, p = fisher_exact([[num_select, num_unselect], [n_total - num_select, n_total - num_unselect]])
        os.append(o)
        ps.append(p)    
        
    df['odds_ratio'] = os
    df['p_value'] = ps
    
    return df

# %%
positive_df = stats_to_df(positive_stats)
negative_df = stats_to_df(negative_stats)
# Out:
#   0%|          | 0/94073 [00:00<?, ?it/s]
#   0%|          | 0/11993 [00:00<?, ?it/s]

# %%
positive_df.to_csv('data/positive_freqs.csv')
negative_df.to_csv('data/negative_freqs.csv')

# %%
positive_df.query('num_select > 50 and num_unselect > 50 and p_value < 5e-2').sort_values('odds_ratio').tail(50)
# Out:
#                                      num_select  num_unselect  odds_ratio  \
# phrase
# leotard                                     381           248    1.540485
# palm trees                                  114            74    1.541799
# official alternate costume                  114            74    1.541799
# stylized                                     94            61    1.542021
# vines                                       112            72    1.556826
# tile based                                13770          9805    1.562010
# color grading                               217           139    1.563642
# black armor                                  86            55    1.564625
# cinematic shot                              253           162    1.564638
# sunbeam                                      94            60    1.567754
# 4girls                                       85            54    1.575070
# modern                                       85            54    1.575070
# detailed beautiful eyes                     112            71    1.578785
# snes                                      12422          8612    1.592251
# glossy skin                                 218           137    1.593878
# veiny penis                                 192           120    1.602356
# machinery                                    94            58    1.621880
# rope                                        119            73    1.631668
# atmospheric lighting                        258           158    1.636255
# thin legs                                   133            81    1.643719
# good anatomy                                211           128    1.651236
# vibrant_color                               127            76    1.672793
# knight                                      127            76    1.672793
# festival                                     89            53    1.680479
# daylight                                    165            98    1.685979
# small tits                                  108            64    1.689016
# trembling                                   295           175    1.689859
# street                                       95            56    1.697779
# fine details                                 89            52    1.712831
# dark shot                                   281           163    1.728094
# object insertion                            101            58    1.742908
# clear line                                  103            59    1.747331
# ultra high definition                       192           110    1.748381
# spikes                                       91            52    1.751393
# video game                                28485         21615    1.757070
# breast press                                135            74    1.826597
# studio soft light                           108            58    1.863969
# environmental 2D                          16698         10394    1.919087
# intricate steampunk+ city                   113            58    1.950463
# nintendo                                    111            56    1.984368
# short black hair                            231           115    2.013464
# 2D side scrolling                         18146         10964    2.039098
# 2D environmental                          17225         10273    2.042457
# dreamlikeart                                114            55    2.075224
# side scrolling video game                 17239         10074    2.096101
# tile based environment                    18805         11031    2.142238
# 2D side scrolling video game              20487         11947    2.226694
# level design                              19201         10552    2.346087
# 2D environmental art side scrolling       22583         12189    2.579044
# 2D environmental side scrolling           22726         12131    2.626046
#
#                                            p_value
# phrase
# leotard                               1.164458e-07
# palm trees                            4.287916e-03
# official alternate costume            4.287916e-03
# stylized                              9.874552e-03
# vines                                 3.884107e-03
# tile based                           1.810665e-193
# color grading                         4.067724e-05
# black armor                           1.119885e-02
# cinematic shot                        8.831220e-06
# sunbeam                               7.581123e-03
# 4girls                                1.062325e-02
# modern                                1.062325e-02
# detailed beautiful eyes               2.975640e-03
# snes                                 9.396636e-194
# glossy skin                           1.946689e-05
# veiny penis                           5.287377e-05
# machinery                             4.340887e-03
# rope                                  1.096603e-03
# atmospheric lighting                  1.026215e-06
# thin legs                             4.556816e-04
# good anatomy                          7.381743e-06
# vibrant_color                         4.161913e-04
# knight                                4.161913e-04
# festival                              3.150179e-03
# daylight                              4.208743e-05
# small tits                            9.757435e-04
# trembling                             3.180314e-08
# street                                1.872641e-03
# fine details                          2.296458e-03
# dark shot                             2.180926e-08
# object insertion                      8.035100e-04
# clear line                            6.744799e-04
# ultra high definition                 2.658935e-06
# spikes                                1.387141e-03
# video game                            0.000000e+00
# breast press                          2.884884e-05
# studio soft light                     1.266481e-04
# environmental 2D                      0.000000e+00
# intricate steampunk+ city             3.091924e-05
# nintendo                              2.466213e-05
# short black hair                      4.077488e-10
# 2D side scrolling                     0.000000e+00
# 2D environmental                      0.000000e+00
# dreamlikeart                          6.518783e-06
# side scrolling video game             0.000000e+00
# tile based environment                0.000000e+00
# 2D side scrolling video game          0.000000e+00
# level design                          0.000000e+00
# 2D environmental art side scrolling   0.000000e+00
# 2D environmental side scrolling       0.000000e+00

# %%
negative_df.query('num_select > 50 and num_unselect > 50 and p_value < 5e-2').sort_values('odds_ratio').tail(50)
# Out:
#                                                     num_select  num_unselect  \
# phrase
# wa_lolita                                                  146           100
# missing_face                                               267           183
# milf                                                        76            52
# big flower                                                  95            65
# moon                                                        98            67
# cloned face                                                193           132
# multiple objects                                           126            86
# fused anatomy                                              106            72
# age spot                                                    96            65
# poorly drawn                                               416           282
# watermarks                                                 317           214
# fused eyes                                                  82            55
# low quality lowres fused clit                              283           190
# camera lens                                                 93            62
# group                                                      107            71
# ugly mouth                                                 149            98
# candle                                                     125            82
# beginner                                                   295           192
# blurry face                                                149            96
# too many fingers                                           315           203
# interlocked leg                                             89            57
# more than two arms                                         133            85
# wrinkles                                                   170           108
# extra vaginal                                              109            69
# nike                                                       105            66
# low quality lowres parts of the body out of com...         236           148
# low quality lowres one hand with less than 5 fi...         273           170
# face out of frame                                          221           137
# multiview                                                  105            65
# |                                                           96            59
# model                                                      166           102
# rgb                                                        119            73
# control mode                                                90            55
# software                                                   111            67
# negativegen                                                162            97
# censor bar                                                  92            55
# low quality lowres more than 2 nipples                     224           134
# contour                                                    127            75
# pink red color                                             126            74
# fused limbs                                                111            65
# 3 hands                                                     96            56
# red hair                                                   104            60
# bad anatomy\fingers\                                       130            75
# model hash                                                 113            65
# more than two leg per body                                 220           123
# no face                                                     96            51
# fused_fingers                                              112            58
# unrealistic eyes                                           104            53
# shadow letters                                             119            60
# see-through                                                103            51
#
#                                                     odds_ratio       p_value
# phrase
# wa_lolita                                             1.461372  3.979249e-03
# missing_face                                          1.461526  8.419640e-05
# milf                                                  1.462254  4.150568e-02
# big flower                                            1.462433  2.146769e-02
# moon                                                  1.463612  1.914112e-02
# cloned face                                           1.463945  8.305208e-04
# multiple objects                                      1.466313  7.188122e-03
# fused anatomy                                         1.473244  1.307601e-02
# age spot                                              1.477857  1.769440e-02
# poorly drawn                                          1.479238  4.043683e-07
# watermarks                                            1.484436  8.527253e-06
# fused eyes                                            1.491730  2.586340e-02
# low quality lowres fused clit                         1.492311  2.108041e-05
# camera lens                                           1.500949  1.561187e-02
# group                                                 1.508150  8.461951e-03
# ugly mouth                                            1.521992  1.396567e-03
# candle                                                1.525729  3.376040e-03
# beginner                                              1.539701  3.321027e-06
# blurry face                                           1.553764  8.443620e-04
# too many fingers                                      1.555287  9.195704e-07
# interlocked leg                                       1.562423  1.000123e-02
# more than two arms                                    1.566240  1.383491e-03
# wrinkles                                              1.576069  2.354998e-04
# extra vaginal                                         1.581000  3.321270e-03
# nike                                                  1.592176  3.509425e-03
# low quality lowres parts of the body out of com...    1.597467  7.941853e-06
# low quality lowres one hand with less than 5 fi...    1.609270  1.071703e-06
# face out of frame                                     1.615911  1.016310e-05
# multiview                                             1.616704  2.650368e-03
# |                                                     1.628347  3.666258e-03
# model                                                 1.629580  1.086374e-04
# rgb                                                   1.631668  1.096603e-03
# control mode                                          1.637532  4.551599e-03
# software                                              1.658205  1.193747e-03
# negativegen                                           1.672321  6.297250e-05
# censor bar                                            1.673990  2.836788e-03
# low quality lowres more than 2 nipples                1.674720  2.179564e-06
# contour                                               1.695131  3.061664e-04
# pink red color                                        1.704511  2.852030e-04
# fused limbs                                           1.709296  6.441349e-04
# 3 hands                                               1.715685  1.463841e-03
# red hair                                              1.734890  7.288026e-04
# bad anatomy\fingers\                                  1.735280  1.469023e-04
# model hash                                            1.740165  3.921836e-04
# more than two leg per body                            1.792168  1.731467e-07
# no face                                               1.884082  2.545434e-04
# fused_fingers                                         1.933163  4.122804e-05
# unrealistic eyes                                      1.964307  5.662898e-05
# shadow letters                                        1.985723  1.206555e-05
# see-through                                           2.021751  3.328868e-05
