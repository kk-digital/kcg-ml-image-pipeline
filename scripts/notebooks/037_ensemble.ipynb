# %%
import numpy as np
import pandas as pd

from utility.ensemble.ensemble_helpers import Binning, SigmaScoresWithEntropy

# %%
values = np.random.rand(1000, 16)
model_ids = np.arange(16)

# %%
binning = Binning(start=-2, count=8, step=0.5)
sigma_scores = SigmaScoresWithEntropy(values, binning)

# %%
binning.thresholds, sigma_scores.p_norm.shape
# Out:
# (array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5]), (1000, 8))

# %%
csv = sigma_scores.to_dataframe()
csv['model_ids'] = ';'.join(map(str, model_ids))
csv
# Out:
#      sigma_score_mean  sigma_score_var  sigma_score_max  sigma_score_min  \
# 0            0.420715         0.099620         0.979599         0.065617
# 1            0.607565         0.064599         0.983214         0.166090
# 2            0.504700         0.067750         0.995096         0.034174
# 3            0.563963         0.080065         0.983233         0.015707
# 4            0.525348         0.087758         0.991452         0.035920
# ..                ...              ...              ...              ...
# 995          0.479430         0.080460         0.889011         0.005318
# 996          0.599182         0.059041         0.916880         0.115083
# 997          0.499865         0.054599         0.969761         0.152541
# 998          0.526033         0.088823         0.951901         0.037160
# 999          0.484405         0.079322         0.971212         0.022511
#
#       entropy  n_models  num_below_start  num_above_end  bin_start  bin_count  \
# ...
